# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/home/jacob/Documents/Python.csv')

# %%
OIIIacc=data['OIII Accretion rate']
Xrayacc=data['Accretion rate (M_solar/yr)']

# %%
x=np.logspace(-8,0,100)
y=x

# %%
plt.loglog(Xrayacc,OIIIacc,'o')
plt.loglog(x,y,c='black',linestyle='--')
plt.xlabel('Accretion rate (x-ray tracer)')
plt.ylabel('Accretion rate (OIII tracer)')
# Out:
# Text(0, 0.5, 'Accretion rate (OIII tracer)')
