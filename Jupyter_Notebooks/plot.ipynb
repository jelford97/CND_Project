# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
liner_radio=np.array([6.33E-02,2.20E+01,3.60E-03])
liner_xray=np.array([1.12E-07,4.90E-08,6.71E-09])
seyfert_radio=np.array([1.03E-01,9.32E-02,np.NaN])
seyfert_xray=np.array([8.34E-09,6.47E-08,7.93E-07])
seyfert2_radio=np.array([7.40E-02,2.50E-03,2.32E-02,7.59E-02,3.76E-02,3.07E-02,2.77E-01,5.14E+00,1.53E-02])
seyfert2_xray=np.array([1.19E-06,6.97E-08,np.NaN,5.59E-09,1.44E-06,2.15E-06,8.16E-09,1.03E-07,np.NaN])
other_radio=np.array([5.70E+00,6.90E-03,2.27E-02])
other_xray=np.array([2.24E-07,2.43E-09,np.NaN])
noclass_radio=np.array([1.00E-04,6.00E-04,1.50E-02,3.10E-03,4.00E-03,np.NaN,4.00E-03,4.86E+00,6.57E-02,3.86E-01,2.81E-02,1.71E-01,1.52E-01,np.NaN,4.25E-02])
noclass_xray=np.array([6.10E-08,3.17E-09,np.NaN,1.34E-07,6.49E-09,np.NaN,2.68E-09,1.40E-08,8.48E-07,np.NaN,6.52E-09,np.NaN,np.NaN,np.NaN,1.06E-07])

# %%
#plt.loglog(radio,x_ray,'o')
#plt.xlabel('radio luminosity(L_solar)')
#plt.ylabel('x ray luminosity(L_solar)')
#plt.title('X ray luminosity vs radio luminosity')

# %%
plt.loglog(liner_radio,liner_xray,'o', color='blue',label='Liner')
plt.loglog(seyfert_radio,seyfert_xray, 'o', color='red',label='Seyfert')
plt.loglog(seyfert2_radio,seyfert2_xray,'o',color='green',label='Seyfert2')
plt.loglog(other_radio,other_xray,'o', color='yellow' ,label='Other')
plt.loglog(noclass_radio,noclass_xray,'o', color='black' ,label='No class')
plt.xlabel('radio flux density(Jy)')
plt.ylabel('X-ray flux density(Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
Jet_radio=np.array([5.70E+00,2.77E-01,5.14E+00,9.32E-02,2.20E+01,4.86E+00,6.57E-02,3.86E-01,np.NaN,2.81E-02,1.53E-02,4.25E-02])
Jet_xray=np.array([2.24E-07,8.16E-09,1.03E-07,6.47E-08,4.90E-08,1.40E-08,8.48E-07,np.NaN,7.93E-07,6.52E-09,np.NaN,1.06E-07])
No_jet_radio=np.array([6.90E-03,7.40E-02,2.50E-03,2.32E-02,7.59E-02,3.76E-02,3.07E-02,1.03E-01,6.33E-02,1.00E-04,6.00E-04,1.50E-02,3.10E-03,4.00E-03,np.NaN,4.00E-03,2.27E-02,3.60E-03,1.71E-01,1.52E-01,np.NaN])
No_jet_xray=np.array([2.43E-09,1.19E-06,6.97E-08,np.NaN,5.59E-09,1.44E-06,2.15E-06,8.34E-09,1.12E-07,6.10E-08,3.17E-09,np.NaN,1.34E-07,6.49E-09,np.NaN,2.68E-09,np.NaN,6.71E-09,np.NaN,np.NaN,np.NaN])

# %%
plt.loglog(Jet_radio, Jet_xray,'o',color='blue', label='Radio Jet')
plt.loglog(No_jet_radio, No_jet_xray,'o',color='red',label='No radio jet')
plt.xlabel('radio flux density(Jy)')
plt.ylabel('x ray density(Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
X_ray_Rosat_2_4kev=np.array([1.19E-06,2.15E-06])
Radio_Rosat_2_4kev=np.array([7.40E-02,3.07E-02])
X_ray_Rosat_2kev=np.array([8.48E-07,1.06E-07])
Radio_Rosat_2kev=np.array([6.57E-02,4.25E-02])
X_ray_einstein=np.array([1.12E-07,6.10E-08,1.34E-07])
Radio_einstein=np.array([6.33E-02,1.00E-04,3.10E-03])
X_ray_chandra=np.array([2.43E-09,1.44E-06,8.34E-09,3.17E-09,6.49E-09,2.24E-07,8.16E-09,6.47E-08,4.90E-08,1.40E-08,6.52E-09,6.71E-09])
Radio_chandra=np.array([6.90E-03,3.76E-02,1.03E-01,6.00E-04,4.00E-03,5.70E+00,2.77E-01,9.32E-02,2.20E+01,4.86E+00,2.81E-02,3.60E-03])
X_ray_XMM=np.array([6.97E-08,5.59E-09,1.03E-07,7.93E-07])
Radio_XMM=np.array([2.50E-03,7.59E-02,5.14E+00,np.NaN])
X_ray_chandra_2380MHz=np.array([2.68E-09])
Radio_chandra_2380MHz=np.array([4.00E-03])

# %%
plt.loglog(Radio_Rosat_2_4kev, X_ray_Rosat_2_4kev,'o',color='red',label='ROSAT 2.4keV')
plt.loglog(Radio_Rosat_2kev, X_ray_Rosat_2kev,'o',color='yellow',label='ROSAT 2keV')
plt.loglog(Radio_einstein,X_ray_einstein,'o',color='blue',label='EINSTEIN 4keV')
plt.loglog(Radio_chandra,X_ray_chandra,'o',color='green',label='CHANDRA 8keV')
plt.loglog(Radio_XMM,X_ray_XMM,'o',color='magenta',label='XMM 10keV')
plt.loglog(Radio_chandra_2380MHz,X_ray_chandra_2380MHz,'o',color='black',label='CHANDRA 2380MHz Radio')
plt.xlabel('radio flux density(Jy)')
plt.ylabel('x ray flux density(Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
xray_detect_other=np.array([2.24E-07,2.43E-09])
mm_detect_other=np.array([8.60E-02,3.06E-03])

xray_detect_seyfert2=np.array([1.19E-06,6.97E-08,8.16E-09,np.NaN,5.59E-09,1.03E-07,1.44E-06,2.15E-06])
mm_detect_seyfert2=np.array([2.62E-03,1.64E-03,2.71E-02,1.33E-03,1.37E-03,2.80E-02,1.41E-02,2.10E-03])

xray_detect_seyfert=np.array([8.34E-09,6.47E-08,7.93E-07])
mm_detect_seyfert=np.array([1.29E-03,2.97E-03,9.03E-04])

xray_detect_liner=np.array([1.12E-07,4.90E-08])
mm_detect_liner=np.array([2.74E-03,3.73E-01])

xray_detect_noclass=np.array([1.40E-08,6.10E-08,3.17E-09,8.48E-07,np.NaN,1.34E-07,6.52E-09,6.49E-09,np.NaN,2.68E-09,np.NaN])
mm_detect_noclass=np.array([6.57E-02,1.46E-03,2.19E-03,2.87E-03,1.54E-02,np.NaN,np.NaN,1.31E-03,2.81E-02,2.10E-03,4.07E-03])

xray_nodetect_other=np.array([np.NaN])
mm_nodetect_other=np.array([1.07E-04])

xray_nodetect_seyfert2=np.array([np.NaN])
mm_nodetect_seyfert2=np.array([1.43E-04])

xray_nodetect_liner=np.array([6.71E-09])
mm_nodetect_liner=np.array([3.66E-05])

xray_nodetect_noclass=np.array([np.NaN,1.06E-07,np.NaN,np.NaN])
mm_nodetect_noclass=np.array([1.36E-04,4.53E-04,7.77E-05,3.09E-04])

xray_uncertaindata_noclass=np.array([7e-9,1.34e-7])
mm_uncertaindata_noclass=([2.71E-02,3.46E-03])

# %%
plt.loglog(mm_detect_liner,xray_detect_liner,'o',color='blue',label='LINER')
plt.loglog(mm_detect_seyfert,xray_detect_seyfert,'o',color='red',label='Seyfert')
plt.loglog(mm_detect_seyfert2,xray_detect_seyfert2,'o',color='green',label='Seyfert2')
plt.loglog(mm_detect_other,xray_detect_other,'o',color='yellow',label='Other')
plt.loglog(mm_detect_noclass,xray_detect_noclass,'o',color='black',label='No Class')
plt.loglog(mm_nodetect_liner,xray_nodetect_liner,'v',color='blue',label='LINER Non-detection')
#plt.loglog(mm_nodetect_seyfert2,xray_nodetect_seyfert2,'v',color='green',label='Seyfert 2 Non-detection')
#plt.loglog(mm_nodetect_other,xray_nodetect_other,'v',color='yellow',label='Other Non-detection')
plt.loglog(mm_nodetect_noclass,xray_nodetect_noclass,'v',color='black',label='No class Non-detection')
#plt.loglog(mm_uncertaindata_noclass,xray_uncertaindata_noclass,'s',color='black',label='No class Uncertain Data')
t
# Out:
# Text(0, 0.5, 'X-ray flux density (Jy)')

# %%
xray_detect_nojet=np.array([2.43E-09,1.19E-06,6.97E-08,np.NaN,5.59E-09,1.44E-06,2.15E-06,8.34E-09,1.12E-07,6.10E-08,3.17E-09,np.NaN,1.34E-07,6.49E-09,np.NaN,2.68E-09])
mm_detect_nojet=np.array([3.06E-03,2.62E-03,1.64E-03,1.33E-03,1.37E-03,1.41E-02,2.10E-03,1.29E-03,2.74E-03,1.46E-03,2.19E-03,1.54E-02,np.NaN,1.31E-03,2.81E-02,2.10E-03])
xray_detect_jet=np.array([2.24E-07,8.16E-09,1.03E-07,6.47E-08,4.90E-08,1.40E-08,8.48E-07,np.NaN,7.93E-07,6.52E-09])
mm_detect_jet=np.array([8.60E-02,2.71E-02,2.80E-02,2.97E-03,3.73E-01,6.57E-02,2.87E-03,4.07E-03,9.03E-04,np.NaN])
xray_nodetect_nojet=np.array([np.NaN,6.71E-09,np.NaN,np.NaN,np.NaN])
mm_nodetect_nojet=np.array([1.07E-04,3.66E-05,1.36E-04,7.77E-05,3.09E-04])
xray_nodetect_jet=np.array([np.NaN,1.06E-07])
mm_nodetect_jet=np.array([1.43E-04,4.53E-04])

# %%
plt.loglog(mm_detect_jet,xray_detect_jet,'o',color='blue',label='Radio jet')
plt.loglog(mm_detect_nojet,xray_detect_nojet,'o',color='red',label='No jet')
plt.loglog(mm_nodetect_jet,xray_nodetect_jet,'v',color='blue',label='Jet non-detection')
plt.loglog(mm_nodetect_nojet,xray_nodetect_nojet,'v',color='red',label='No jet non-detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('mm flux density (Jy)')
plt.ylabel('X-ray flux density (Jy)')
# Out:
# Text(0, 0.5, 'X-ray flux density (Jy)')

# %%
radio_detect_other=np.array([5.70E+00,6.90E-03])
radio_detect_seyfert2=np.array([7.40E-02,3.07E-02,3.76E-02,2.77E-01,2.50E-03,7.59E-02,5.14E+00,2.32E-02])
radio_detect_seyfert=np.array([1.03E-01,9.32E-02,np.NaN])
radio_detect_liner=np.array([6.33E-02,2.20E+01])
radio_detect_noclass=np.array([6.57E-02,1.00E-04,3.10E-03,6.00E-04,4.00E-03,4.00E-03,4.86E+00,2.81E-02,1.50E-02,np.NaN,3.86E-01,2.08E-01])
radio_nodetect_other=np.array([2.27E-02])
radio_nodetect_seyfert2=np.array([1.53E-02])
radio_nodetect_liner=np.array([3.60E-03])
radio_nodetect_noclass=np.array([1.71E-01,1.52E-01,np.NaN,4.25E-02])
mm_detect_other_radio=np.array([8.60E-02,3.06E-03])
mm_detect_seyfert2_radio=np.array([2.62E-03,2.10E-03,1.41E-02,2.71E-02,1.64E-03,1.37E-03,2.80E-02,1.33E-03])
mm_detect_seyfert_radio=np.array([1.29E-03,2.97E-03,9.03E-04])
mm_detect_liner_radio=np.array([2.74E-03,3.73E-01])
mm_detect_noclass_radio=np.array([2.87E-03,1.46E-03,np.NaN,2.19E-03,1.31E-03,2.10E-03,6.57E-02,np.NaN,1.54E-02,2.81E-02,4.07E-03,2.71E-02])
mm_nodetect_other_radio=np.array([1.07E-04])
mm_nodetect_seyfert2_radio=np.array([1.43E-04])
mm_nodetect_liner_radio=np.array([3.66E-05])
mm_nodetect_noclass_radio=np.array([1.36E-04,7.77E-05,3.09E-04,4.53E-04])

# %%
plt.loglog(mm_detect_liner_radio,radio_detect_liner,'o',color='blue',label='LINER')
plt.loglog(mm_detect_seyfert_radio,radio_detect_seyfert,'o',color='red',label='Seyfert')
plt.loglog(mm_detect_seyfert2_radio,radio_detect_seyfert2,'o',color='green',label='Seyfert2')
plt.loglog(mm_detect_other_radio,radio_detect_other,'o',color='yellow',label='Other')
plt.loglog(mm_detect_noclass_radio,radio_detect_noclass,'o',color='black',label='No class')
plt.loglog(mm_nodetect_liner_radio,radio_nodetect_liner,'v',color='blue',label='LINER non-detection')
plt.loglog(mm_nodetect_seyfert2_radio,radio_nodetect_seyfert2,'v',color='green',label='Seyfert2 non-detection')
plt.loglog(mm_nodetect_other_radio,radio_nodetect_other,'v',color='yellow',label='Other non-detection')
plt.loglog(mm_nodetect_noclass_radio,radio_nodetect_noclass,'v',color='black',label='No class non-detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('mm flux density (Jy)')
plt.ylabel('Radio flux density (Jy)')
# Out:
# Text(0, 0.5, 'Radio flux density (Jy)')

# %%
radio_detect_nojet=np.array([6.90E-03,7.40E-02,3.07E-02,3.76E-02,2.50E-03,7.59E-02,2.32E-02,1.03E-01,6.33E-02,1.00E-04,3.10E-03,6.00E-04,4.00E-03,4.00E-03,1.50E-02,np.NaN])
radio_detect_jet=np.array([5.70E+00,2.77E-01,5.14E+00,9.32E-02,2.20E+01,6.57E-02,4.86E+00,3.86E-01,np.NaN,2.81E-02,2.08E-01])
radio_nodetect_nojet=np.array([2.27E-02,3.60E-03,1.71E-01,1.52E-01,np.NaN])
radio_nodetect_jet=np.array([1.53E-02,4.25E-02])
mm_detect_nojet_radio=np.array([3.06E-03,2.62E-03,2.10E-03,1.41E-02,1.64E-03,1.37E-03,1.33E-03,1.29E-03,2.74E-03,1.46E-03,np.NaN,2.19E-03,1.31E-03,2.10E-03,1.54E-02,2.81E-02])
mm_detect_jet_radio=np.array([8.60E-02,2.71E-02,2.80E-02,2.97E-03,3.73E-01,2.87E-03,6.57E-02,4.07E-03,9.03E-04,np.NaN,2.71E-02])
mm_nodetect_nojet_radio=np.array([1.07E-04,3.66E-05,1.36E-04,7.77E-05,3.09E-04])
mm_nodetect_jet_radio=np.array([1.43E-04,4.53E-04])

# %%
plt.loglog(mm_detect_jet_radio,radio_detect_jet,'o',color='blue',label='Radio jet')
plt.loglog(mm_detect_nojet_radio,radio_detect_nojet,'o',color='red',label='No jet')
plt.loglog(mm_nodetect_jet_radio,radio_nodetect_jet,'v',color='blue',label='Radio Jet Non-detetction')
plt.loglog(mm_nodetect_nojet_radio,radio_nodetect_nojet,'v',color='red',label='No jet Non-detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('mm flux density (Jy)')
plt.ylabel('Radio flux density (Jy)')
# Out:
# Text(0, 0.5, 'Radio flux density (Jy)')

# %%
xrayflux=np.array([7.93E-07,1.19E-06,1.40E-08,5.59E-09,1.34E-07,1.03E-07,8.48E-07,6.97E-08,6.49E-09,np.NaN,6.47E-08,6.52E-09,2.43E-09,2.24E-07,np.NaN,4.90E-08,6.10E-08,2.68E-09,1.12E-07,8.16E-09,3.17E-09,8.34E-09,np.NaN,2.15E-06,np.NaN,1.44E-06,np.NaN,6.71E-09,1.06E-07,np.NaN,np.NaN,np.NaN,np.NaN])
mass100pcxray=np.array([np.NaN,1.13E+08,4.23E+07,np.NaN,4.36E+06,np.NaN,1.49E+08,1.41E+07,8.13E+06,np.NaN,7.72E+07,1.23E+08,5.99E+07,np.NaN,np.NaN,np.NaN,5.76E+06,5.18E+07,1.04E+08,7.53E+07,1.15E+06,np.NaN,np.NaN,np.NaN,5.96E+07,np.NaN,2.16E+08,1.40E+06,np.NaN,1.42E+08,2.51E+07,1.05E+08,np.NaN])

# %%
plt.loglog(mass100pcxray,xrayflux,'o')
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('X-ray flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray flux (Jy)')

# %%
mass75pcxray=np.array([np.NaN,np.NaN,2.41E+07,np.NaN,2.78E+06,np.NaN,9.49E+07,9.45E+06,4.27E+06,np.NaN,4.75E+07,8.24E+07,4.18E+07,np.NaN,np.NaN,np.NaN,2.84E+06,3.53E+07,6.53E+07,5.03E+07,1.17E+06,np.NaN,np.NaN,np.NaN,3.88E+07,np.NaN,np.NaN,5.09E+05,np.NaN,8.82E+07,1.90E+07,6.35E+07,np.NaN])

# %%
plt.loglog(mass75pcxray,xrayflux,'o')
plt.xlabel('Mass of a 75pc region (Solar Masses)')
plt.ylabel('X-ray flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray flux (Jy)')

# %%
mass50pcxray=np.array([np.NaN,np.NaN,1.03E+07,np.NaN,1.38E+06,np.NaN,4.59E+07,np.NaN,1.96E+06,np.NaN,np.NaN,4.56E+07,np.NaN,np.NaN,np.NaN,np.NaN,8.48E+05,1.77E+07,3.14E+07,2.61E+07,1.03E+06,np.NaN,np.NaN,np.NaN,1.72E+07,np.NaN,np.NaN,1.76E+05,np.NaN,3.99E+07,1.15E+07,3.10E+07,np.NaN])

# %%
plt.loglog(mass50pcxray,xrayflux,'o')
plt.xlabel('Mass of a 50pc region (Solar Masses)')
plt.ylabel('X-ray flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray flux (Jy)')

# %%
mass25pcxray=np.array([np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,1.45E+07,np.NaN,np.NaN,np.NaN,np.NaN,1.39E+07,np.NaN,np.NaN,np.NaN,np.NaN,6.92E+04,4.13E+06,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,2.82E+06,np.NaN,np.NaN,2.04E+05,np.NaN,1.13E+07,np.NaN,np.NaN,np.NaN])

# %%
plt.loglog(mass25pcxray,xrayflux,'o')
plt.xlabel('Mass of a 25pc region (Solar Masses)')
plt.ylabel('X-ray flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray flux (Jy)')

# %%
radioflux=np.array([np.NaN,7.40E-02,4.86E+00,7.59E-02,3.10E-03,5.14E+00,6.57E-02,2.50E-03,4.00E-03,np.NaN,9.32E-02,2.81E-02,6.90E-03,5.70E+00,3.86E-01,2.20E+01,1.00E-04,4.00E-03,6.33E-02,2.77E-01,6.00E-04,1.03E-01,2.32E-02,3.07E-02,1.50E-02,3.76E-02,2.27E-02,3.60E-03,4.25E-02,1.52E-01,1.53E-02,1.71E-01,np.NaN,2.08E-01])
mass100pcradio=np.array([np.NaN,1.13E+08,4.23E+07,np.NaN,4.36E+06,np.NaN,1.49E+08,1.41E+07,8.13E+06,np.NaN,7.72E+07,1.23E+08,5.99E+07,np.NaN,np.NaN,np.NaN,5.76E+06,5.18E+07,1.04E+08,7.53E+07,1.15E+06,np.NaN,np.NaN,np.NaN,5.96E+07,np.NaN,2.16E+08,1.40E+06,np.NaN,1.42E+08,2.51E+07,1.05E+08,np.NaN,1.07E+08])

# %%
plt.loglog(mass100pcradio,radioflux, 'o')
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('Radio flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio flux (Jy)')

# %%
mass75pcradio=np.array([np.NaN,np.NaN,2.41E+07,np.NaN,2.78E+06,np.NaN,9.49E+07,9.45E+06,4.27E+06,np.NaN,4.75E+07,8.24E+07,4.18E+07,np.NaN,np.NaN,np.NaN,2.84E+06,3.53E+07,6.53E+07,5.03E+07,1.17E+06,np.NaN,np.NaN,np.NaN,3.88E+07,np.NaN,np.NaN,5.09E+05,np.NaN,8.82E+07,1.90E+07,6.35E+07,np.NaN,6.11E+07])

# %%
plt.loglog(mass75pcradio,radioflux, 'o')
plt.xlabel('Mass of a 75pc region (Solar Masses)')
plt.ylabel('Radio flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio flux (Jy)')

# %%
mass50pcradio=np.array([np.NaN,np.NaN,1.03E+07,np.NaN,1.38E+06,np.NaN,4.59E+07,np.NaN,1.96E+06,np.NaN,np.NaN,4.56E+07,np.NaN,np.NaN,np.NaN,np.NaN,8.48E+05,1.77E+07,3.14E+07,2.61E+07,1.03E+06,np.NaN,np.NaN,np.NaN,1.72E+07,np.NaN,np.NaN,1.76E+05,np.NaN,3.99E+07,1.15E+07,3.10E+07,np.NaN,2.58E+07])

# %%
plt.loglog(mass50pcradio,radioflux, 'o')
plt.xlabel('Mass of a 50pc region (Solar Masses)')
plt.ylabel('Radio flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio flux (Jy)')

# %%
mass25pcradio=np.array([np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,1.45E+07,np.NaN,np.NaN,np.NaN,np.NaN,1.39E+07,np.NaN,np.NaN,np.NaN,np.NaN,6.92E+04,4.13E+06,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,2.82E+06,np.NaN,np.NaN,2.04E+05,np.NaN,1.13E+07,np.NaN,np.NaN,np.NaN,np.NaN])

# %%
plt.loglog(mass25pcradio,radioflux, 'o')
plt.xlabel('Mass of a 25pc region (Solar Masses)')
plt.ylabel('Radio flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio flux (Jy)')

# %%
mmflux_detect=np.array([9.03E-04,2.62E-03,6.57E-02,1.37E-03,np.NaN,2.80E-02,2.87E-03,1.64E-03,1.31E-03,2.81E-02,2.97E-03,np.NaN,3.06E-03,8.60E-02,4.07E-03,3.73E-01,1.46E-03,2.10E-03,2.74E-03,2.71E-02,2.19E-03,1.29E-03,1.33E-03,2.10E-03,1.54E-02,1.41E-02,3.46E-03,2.71E-02])
mmflux_nodetect=np.array([1.07E-04,3.66E-05,4.53E-04,7.77E-05,1.43E-04,1.36E-04,3.09E-04])
mass100pcmm_detect=np.array([np.NaN,7.82E+07,5.60E+07,np.NaN,8.86E+06,np.NaN,4.77E+07,1.41E+07,1.16E+07,np.NaN,6.49E+07,7.63E+07,3.32E+07,np.NaN,np.NaN,np.NaN,1.89E+06,1.83E+07,6.16E+07,5.41E+07,9.81E+05,np.NaN,np.NaN,np.NaN,4.06E+07,np.NaN,5.69E+06,5.43E+07])
mass100pcmm_nodetect=np.array([3.63E+08,1.37E+06,np.NaN,4.90E+07,1.48E+07,1.52E+08,np.NaN])

# %%
plt.loglog(mass100pcmm_detect,mmflux_detect, 'o', label='Detection')
plt.loglog(mass100pcmm_nodetect,mmflux_nodetect, 'v', label='No detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
mass75pcmm_detect=np.array([np.NaN,np.NaN,2.41E+07,np.NaN,2.78E+06,np.NaN,9.49E+07,9.45E+06,4.27E+06,np.NaN,4.75E+07,8.24E+07,4.18E+07,np.NaN,np.NaN,np.NaN,2.84E+06,3.53E+07,6.53E+07,5.03E+07,1.17E+06,np.NaN,np.NaN,np.NaN,3.88E+07,np.NaN,2.82E+06,6.11E+07])
mass75pcmm_nodetect=np.array([np.NaN,5.09E+05,np.NaN,8.82E+07,1.90E+07,6.35E+07,np.NaN])

# %%
plt.loglog(mass75pcmm_detect,mmflux_detect, 'o', label='Detection')
plt.loglog(mass75pcmm_nodetect,mmflux_nodetect, 'v', label='No detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 75pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
mass50pcmm_detect=np.array([np.NaN,np.NaN,1.03E+07,np.NaN,1.38E+06,np.NaN,4.59E+07,np.NaN,1.96E+06,np.NaN,np.NaN,4.56E+07,np.NaN,np.NaN,np.NaN,np.NaN,8.48E+05,1.77E+07,3.14E+07,2.61E+07,1.03E+06,np.NaN,np.NaN,np.NaN,1.72E+07,np.NaN,1.57E+06,2.58E+07])
mass50pcmm_nodetect=np.array([np.NaN,1.76E+05,np.NaN,3.99E+07,1.15E+07,3.10E+07,np.NaN])

# %%
plt.loglog(mass50pcmm_detect,mmflux_detect, 'o', label='Detection')
plt.loglog(mass50pcmm_nodetect,mmflux_nodetect, 'v', label='No detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 50pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
mass25pcmm_detect=np.array([np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,1.45E+07,np.NaN,np.NaN,np.NaN,np.NaN,1.39E+07,np.NaN,np.NaN,np.NaN,np.NaN,6.92E+04,4.13E+06,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,2.82E+06,np.NaN,5.64E+05,np.NaN])
mass25pcmm_nodetect=np.array([np.NaN,2.04E+05,np.NaN,1.13E+07,np.NaN,np.NaN,np.NaN])

# %%
plt.loglog(mass25pcmm_detect,mmflux_detect, 'o', label='Detection')
plt.loglog(mass25pcmm_nodetect,mmflux_nodetect, 'v', label='No detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 25pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')
