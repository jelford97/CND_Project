# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import math
from sauron_colormap import sauron

# %%
plt.rcParams['font.family'] = 'Latin Modern Roman'
plt.rcParams.update({'font.size': 10})
plt.rcParams['legend.fontsize'] = 14
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['xtick.labelsize'] = 12;
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['xtick.major.size'] = 10;
plt.rcParams['ytick.major.size'] = 10
plt.rcParams['xtick.major.width'] = 2;
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['xtick.minor.size'] = 5;
plt.rcParams['ytick.minor.size'] = 5
plt.rcParams['xtick.minor.width'] = 1;
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.direction'] = 'in';
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.bottom'] = True
plt.rcParams['ytick.left'] = True
params = {'mathtext.default': 'regular'}
plt.rcParams.update(params)
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['ytick.right']=True
plt.rcParams['xtick.top']=True

# %%
data=pd.read_csv('Documents/Python.csv')

# %%
mass100pc=data['Mass 100pc']

# %%
xraydata=data['X-ray flux density(Jy)']

# %%
plt.loglog(mass100pc,xraydata,'o')
plt.xlabel('Mass 100pc Region (solar masses)')
plt.ylabel('X-ray flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray flux (Jy)')

# %%
mass75pc=data['Mass 75pc']

# %%
plt.loglog(mass75pc,xraydata,'o')
plt.xlabel('Mass 75pc Region (solar masses)')
plt.ylabel('X-ray flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray flux (Jy)')

# %%
mass50pc=data['Mass 50pc'].values

# %%
plt.loglog(mass50pc,xraydata,'o')
plt.xlabel('Mass 50pc Region (solar masses)')
plt.ylabel('X-ray flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray flux (Jy)')

# %%
mass25pc=data['Mass 25pc'].values

# %%
plt.loglog(mass25pc,xraydata,'o')
plt.xlabel('Mass 25pc Region (solar masses)')
plt.ylabel('X-ray flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray flux (Jy)')

# %%
radiodata=data['Radio Flux (Jy)'].values

# %%
plt.loglog(mass100pc,radiodata,'o')
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('Radio flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio flux (Jy)')

# %%
plt.loglog(mass75pc,radiodata,'o')
plt.xlabel('Mass of a 75pc region (Solar Masses)')
plt.ylabel('Radio flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio flux (Jy)')

# %%
plt.loglog(mass50pc,radiodata,'o')
plt.xlabel('Mass of a 50pc region (Solar Masses)')
plt.ylabel('Radio flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio flux (Jy)')

# %%
plt.loglog(mass25pc,radiodata,'o')
plt.xlabel('Mass of a 25pc region (Solar Masses)')
plt.ylabel('Radio flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio flux (Jy)')

# %%
detections=data[data['Detection']=='Yes']

# %%
nodetection=data[data['Detection']=='No']

# %%
detectionmm=detections['1mm flux density (Jy)']

# %%
nodetectionmm=nodetection['1mm flux density (Jy)']

# %%
mass100pcdect=detections['Mass 100pc']
mass100pcnodect=nodetection['Mass 100pc']

# %%
plt.loglog(mass100pcdect,detectionmm,'o',label='Detection')
plt.loglog(mass100pcnodect,nodetectionmm,'v',label='No Detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
mass75pcdect=detections['Mass 75pc']
mass75pcnodect=nodetection['Mass 75pc']

# %%
plt.loglog(mass75pcdect,detectionmm,'o',label='Detections')
plt.loglog(mass75pcnodect,nodetectionmm,'v',label='No Detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 75pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
mass50pcdect=detections['Mass 50pc']
mass50pcnodect=nodetection['Mass 50pc']

# %%
plt.loglog(mass50pcdect,detectionmm,'o',label='Detections')
plt.loglog(mass50pcnodect,nodetectionmm,'v',label='No Detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 50pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
mass25pcdect=detections['Mass 25pc']
mass25pcnodect=nodetection['Mass 25pc']

# %%
plt.loglog(mass25pcdect,detectionmm,'o',label='Detections')
plt.loglog(mass25pcnodect,nodetectionmm,'v',label='No Detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 25pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
data100pcradio=data[['Radio Flux (Jy)','Mass 100pc']]

# %%
data100pcradionew=data100pcradio.dropna()

# %%
stats.spearmanr(data100pcradionew['Mass 100pc'],data100pcradionew['Radio Flux (Jy)'])
# Out:
# SpearmanrResult(correlation=0.7469958172474642, pvalue=9.996423829698674e-05)

# %%
data75pcradio=data[['Radio Flux (Jy)','Mass 75pc']]

# %%
data75pcradionew=data75pcradio.dropna()

# %%
stats.spearmanr(data75pcradionew['Mass 75pc'],data75pcradionew['Radio Flux (Jy)'])
# Out:
# SpearmanrResult(correlation=0.8003511082021134, pvalue=3.870651417508021e-05)

# %%
data50pcradio=data[['Radio Flux (Jy)','Mass 50pc']]

# %%
data50pcradionew=data50pcradio.dropna()

# %%
stats.spearmanr(data50pcradionew['Mass 50pc'],data50pcradionew['Radio Flux (Jy)'])
# Out:
# SpearmanrResult(correlation=0.8005888848791539, pvalue=0.0001948411220770617)

# %%
data25pcradio=data[['Radio Flux (Jy)','Mass 25pc']]

# %%
data25pcradionew=data25pcradio.dropna()

# %%
stats.spearmanr(data25pcradionew['Mass 25pc'],data25pcradionew['Radio Flux (Jy)'])
# Out:
# SpearmanrResult(correlation=0.8571428571428573, pvalue=0.01369732661532562)

# %%
liner=data[data['AGN Class']=='LINER']

# %%
seyfert=data[data['AGN Class']=='Seyfert']

# %%
seyfert2=data[data['AGN Class']=='Seyfert 2']

# %%
other=data[data['AGN Class']=='Other']

# %%
noclass=data[data['AGN Class']=='No class']

# %%
plt.loglog(liner['Mass 100pc'],liner['Radio Flux (Jy)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 100pc'],liner['Radio Flux (Jy)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2['Mass 100pc'],seyfert2['Radio Flux (Jy)'],'o',color='green',label='Seyfert 2')
plt.loglog(other['Mass 100pc'],other['Radio Flux (Jy)'],'o',color='yellow',label='Other')
plt.loglog(noclass['Mass 100pc'], noclass['Radio Flux (Jy)'], 'o', color='black',label='No class')
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('Radio flux (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.loglog(liner['Mass 75pc'],liner['Radio Flux (Jy)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 75pc'],liner['Radio Flux (Jy)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2['Mass 75pc'],seyfert2['Radio Flux (Jy)'],'o',color='green',label='Seyfert 2')
plt.loglog(other['Mass 75pc'],other['Radio Flux (Jy)'],'o',color='yellow',label='Other')
plt.loglog(noclass['Mass 75pc'], noclass['Radio Flux (Jy)'], 'o',color='black', label='No class')
plt.xlabel('Mass of a 75pc region (Solar Masses)')
plt.ylabel('Radio flux (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.loglog(liner['Mass 50pc'],liner['Radio Flux (Jy)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 50pc'],liner['Radio Flux (Jy)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2['Mass 50pc'],seyfert2['Radio Flux (Jy)'],'o',color='green',label='Seyfert 2')
plt.loglog(other['Mass 50pc'],other['Radio Flux (Jy)'],'o',color='yellow',label='Other')
plt.loglog(noclass['Mass 50pc'], noclass['Radio Flux (Jy)'], 'o', color='black',label='No class')
plt.xlabel('Mass of a 50pc region (Solar Masses)')
plt.ylabel('Radio flux (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.loglog(liner['Mass 25pc'],liner['Radio Flux (Jy)'],'o', color='blue', label='LINER')
plt.loglog(seyfert['Mass 25pc'],liner['Radio Flux (Jy)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2['Mass 25pc'],seyfert2['Radio Flux (Jy)'],'o',color='green',label='Seyfert 2')
plt.loglog(other['Mass 25pc'],other['Radio Flux (Jy)'],'o',color='yellow', label='Other')
plt.loglog(noclass['Mass 25pc'], noclass['Radio Flux (Jy)'], 'o', color='black', label='No class')
plt.xlabel('Mass of a 25pc region (Solar Masses)')
plt.ylabel('Radio flux (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.loglog(liner['Mass 100pc'],liner['X-ray flux density(Jy)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 100pc'],liner['X-ray flux density(Jy)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2['Mass 100pc'],seyfert2['X-ray flux density(Jy)'],'o',color='green',label='Seyfert 2')
plt.loglog(other['Mass 100pc'],other['X-ray flux density(Jy)'],'o',color='yellow',label='Other')
plt.loglog(noclass['Mass 100pc'], noclass['X-ray flux density(Jy)'], 'o', color='black',label='No class')
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('X-ray flux (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.loglog(liner['Mass 75pc'],liner['X-ray flux density(Jy)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 75pc'],liner['X-ray flux density(Jy)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2['Mass 75pc'],seyfert2['X-ray flux density(Jy)'],'o',color='green',label='Seyfert 2')
plt.loglog(other['Mass 75pc'],other['X-ray flux density(Jy)'],'o',color='yellow',label='Other')
plt.loglog(noclass['Mass 75pc'], noclass['X-ray flux density(Jy)'], 'o', color='black',label='No class')
plt.xlabel('Mass of a 75pc region (Solar Masses)')
plt.ylabel('X-ray flux (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.loglog(liner['Mass 50pc'],liner['X-ray flux density(Jy)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 50pc'],liner['X-ray flux density(Jy)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2['Mass 50pc'],seyfert2['X-ray flux density(Jy)'],'o',color='green',label='Seyfert 2')
plt.loglog(other['Mass 50pc'],other['X-ray flux density(Jy)'],'o',color='yellow',label='Other')
plt.loglog(noclass['Mass 50pc'], noclass['X-ray flux density(Jy)'], 'o', color='black',label='No class')
plt.xlabel('Mass of a 50pc region (Solar Masses)')
plt.ylabel('X-ray flux (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.loglog(liner['Mass 25pc'],liner['X-ray flux density(Jy)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 25pc'],liner['X-ray flux density(Jy)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2['Mass 25pc'],seyfert2['X-ray flux density(Jy)'],'o',color='green',label='Seyfert 2')
plt.loglog(other['Mass 25pc'],other['X-ray flux density(Jy)'],'o',color='yellow',label='Other')
plt.loglog(noclass['Mass 25pc'], noclass['X-ray flux density(Jy)'], 'o', color='black',label='No class')
plt.xlabel('Mass of a 25pc region (Solar Masses)')
plt.ylabel('X-ray flux (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
linerdect=liner[liner['Detection']=='Yes']
seyfert2dect=seyfert2[seyfert2['Detection']=='Yes']
otherdect=other[other['Detection']=='Yes']
noclassdect=noclass[noclass['Detection']=='Yes']
linernodect=liner[liner['Detection']=='No']
seyfert2nodect=seyfert2[seyfert2['Detection']=='No']
othernodect=other[other['Detection']=='No']
noclassnodect=noclass[noclass['Detection']=='No']

# %%
plt.loglog(linerdect['Mass 100pc'],linerdect['1mm flux density (Jy)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 100pc'],seyfert['1mm flux density (Jy)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2dect['Mass 100pc'],seyfert2dect['1mm flux density (Jy)'],'o',color='green',label='Seyfert 2')
plt.loglog(otherdect['Mass 100pc'],otherdect['1mm flux density (Jy)'],'o',color='yellow',label='Other')
plt.loglog(noclassdect['Mass 100pc'],noclassdect['1mm flux density (Jy)'],'o',color='black',label='No class')
plt.loglog(linernodect['Mass 100pc'],linernodect['1mm flux density (Jy)'],'v',color='blue',label='LINER non-detection')
plt.loglog(seyfert2nodect['Mass 100pc'],seyfert2nodect['1mm flux density (Jy)'],'v',color='green',label='Seyfert2 non-detection')
plt.loglog(othernodect['Mass 100pc'],othernodect['1mm flux density (Jy)'],'v',color='yellow',label='Other non-detection')
plt.loglog(noclassnodect['Mass 100pc'],noclassnodect['1mm flux density (Jy)'],'v',color='black',label='No class non detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
plt.loglog(linerdect['Mass 75pc'],linerdect['1mm flux density (Jy)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 75pc'],seyfert['1mm flux density (Jy)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2dect['Mass 75pc'],seyfert2dect['1mm flux density (Jy)'],'o',color='green',label='Seyfert 2')
plt.loglog(otherdect['Mass 75pc'],otherdect['1mm flux density (Jy)'],'o',color='yellow',label='Other')
plt.loglog(noclassdect['Mass 75pc'],noclassdect['1mm flux density (Jy)'],'o',color='black',label='No class')
plt.loglog(linernodect['Mass 75pc'],linernodect['1mm flux density (Jy)'],'v',color='blue',label='LINER non-detection')
plt.loglog(seyfert2nodect['Mass 75pc'],seyfert2nodect['1mm flux density (Jy)'],'v',color='green',label='Seyfert2 non-detection')
plt.loglog(othernodect['Mass 75pc'],othernodect['1mm flux density (Jy)'],'v',color='yellow',label='Other non-detection')
plt.loglog(noclassnodect['Mass 75pc'],noclassnodect['1mm flux density (Jy)'],'v',color='black',label='No class non detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 75pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
plt.loglog(linerdect['Mass 50pc'],linerdect['1mm flux density (Jy)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 50pc'],seyfert['1mm flux density (Jy)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2dect['Mass 50pc'],seyfert2dect['1mm flux density (Jy)'],'o',color='green',label='Seyfert 2')
plt.loglog(otherdect['Mass 50pc'],otherdect['1mm flux density (Jy)'],'o',color='yellow',label='Other')
plt.loglog(noclassdect['Mass 50pc'],noclassdect['1mm flux density (Jy)'],'o',color='black',label='No class')
plt.loglog(linernodect['Mass 50pc'],linernodect['1mm flux density (Jy)'],'v',color='blue',label='LINER non-detection')
plt.loglog(seyfert2nodect['Mass 50pc'],seyfert2nodect['1mm flux density (Jy)'],'v',color='green',label='Seyfert2 non-detection')
plt.loglog(othernodect['Mass 50pc'],othernodect['1mm flux density (Jy)'],'v',color='yellow',label='Other non-detection')
plt.loglog(noclassnodect['Mass 50pc'],noclassnodect['1mm flux density (Jy)'],'v',color='black',label='No class non detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 50pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
plt.loglog(linerdect['Mass 25pc'],linerdect['1mm flux density (Jy)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 25pc'],seyfert['1mm flux density (Jy)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2dect['Mass 25pc'],seyfert2dect['1mm flux density (Jy)'],'o',color='green',label='Seyfert 2')
plt.loglog(otherdect['Mass 25pc'],otherdect['1mm flux density (Jy)'],'o',color='yellow',label='Other')
plt.loglog(noclassdect['Mass 25pc'],noclassdect['1mm flux density (Jy)'],'o',color='black',label='No class')
plt.loglog(linernodect['Mass 25pc'],linernodect['1mm flux density (Jy)'],'v',color='blue',label='LINER non-detection')
plt.loglog(seyfert2nodect['Mass 25pc'],seyfert2nodect['1mm flux density (Jy)'],'v',color='green',label='Seyfert2 non-detection')
plt.loglog(othernodect['Mass 25pc'],othernodect['1mm flux density (Jy)'],'v',color='yellow',label='Other non-detection')
plt.loglog(noclassnodect['Mass 25pc'],noclassnodect['1mm flux density (Jy)'],'v',color='black',label='No class non detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 25pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
jet=data[data['Radio Jet']=='Yes']
nojet=data[data['Radio Jet']=='No']

# %%
plt.loglog(jet['Mass 100pc'],jet['Radio Flux (Jy)'],'o', color='blue',label='Jet')
plt.loglog(nojet['Mass 100pc'],nojet['Radio Flux (Jy)'],'o',color='red',label='No jet')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('Radio Flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio Flux (Jy)')

# %%
plt.loglog(jet['Mass 75pc'],jet['Radio Flux (Jy)'],'o', color='blue',label='Jet')
plt.loglog(nojet['Mass 75pc'],nojet['Radio Flux (Jy)'],'o',color='red',label='No jet')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 75pc region (Solar Masses)')
plt.ylabel('Radio Flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio Flux (Jy)')

# %%
plt.loglog(jet['Mass 50pc'],jet['Radio Flux (Jy)'],'o', color='blue',label='Jet')
plt.loglog(nojet['Mass 50pc'],nojet['Radio Flux (Jy)'],'o',color='red',label='No jet')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 50pc region (Solar Masses)')
plt.ylabel('Radio Flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio Flux (Jy)')

# %%
plt.loglog(jet['Mass 25pc'],jet['Radio Flux (Jy)'],'o', color='blue',label='Jet')
plt.loglog(nojet['Mass 25pc'],nojet['Radio Flux (Jy)'],'o',color='red',label='No jet')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 25pc region (Solar Masses)')
plt.ylabel('Radio Flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio Flux (Jy)')

# %%
plt.loglog(jet['Mass 100pc'],jet['X-ray flux density(Jy)'],'o',color='blue',label='Jet')
plt.loglog(nojet['Mass 100pc'],nojet['X-ray flux density(Jy)'],'o',color='red',label='No jet')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('X-ray Flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray Flux (Jy)')

# %%
plt.loglog(jet['Mass 75pc'],jet['X-ray flux density(Jy)'],'o',color='blue',label='Jet')
plt.loglog(nojet['Mass 75pc'],nojet['X-ray flux density(Jy)'],'o',color='red',label='No jet')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 75pc region (Solar Masses)')
plt.ylabel('X-ray Flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray Flux (Jy)')

# %%
plt.loglog(jet['Mass 50pc'],jet['X-ray flux density(Jy)'],'o',color='blue',label='Jet')
plt.loglog(nojet['Mass 50pc'],nojet['X-ray flux density(Jy)'],'o',color='red',label='No jet')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 50pc region (Solar Masses)')
plt.ylabel('X-ray Flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray Flux (Jy)')

# %%
plt.loglog(jet['Mass 25pc'],jet['X-ray flux density(Jy)'],'o',color='blue',label='Jet')
plt.loglog(nojet['Mass 25pc'],nojet['X-ray flux density(Jy)'],'o',color='red',label='No jet')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 25pc region (Solar Masses)')
plt.ylabel('X-ray Flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray Flux (Jy)')

# %%
jetdect=jet[jet['Detection']=='Yes']
nojetdect=nojet[nojet['Detection']=='Yes']
jetnodect=jet[jet['Detection']=='No']
nojetnodect=nojet[nojet['Detection']=='No']

# %%
plt.loglog(jetdect['Mass 100pc'],jetdect['1mm flux density (Jy)'],'o',color='blue',label='Jet')
plt.loglog(nojetdect['Mass 100pc'],nojetdect['1mm flux density (Jy)'],'o',color='red',label='No jet')
plt.loglog(jetnodect['Mass 100pc'],jetnodect['1mm flux density (Jy)'],'v',color='blue',label='Jet non-detection')
plt.loglog(nojetnodect['Mass 100pc'],nojetnodect['1mm flux density (Jy)'],'v',color='red',label='No jet non-detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
plt.loglog(jetdect['Mass 75pc'],jetdect['1mm flux density (Jy)'],'o',color='blue',label='Jet')
plt.loglog(nojetdect['Mass 75pc'],nojetdect['1mm flux density (Jy)'],'o',color='red',label='No jet')
plt.loglog(jetnodect['Mass 75pc'],jetnodect['1mm flux density (Jy)'],'v',color='blue',label='Jet non-detection')
plt.loglog(nojetnodect['Mass 75pc'],nojetnodect['1mm flux density (Jy)'],'v',color='red',label='No jet non-detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 75pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
plt.loglog(jetdect['Mass 50pc'],jetdect['1mm flux density (Jy)'],'o',color='blue',label='Jet')
plt.loglog(nojetdect['Mass 50pc'],nojetdect['1mm flux density (Jy)'],'o',color='red',label='No jet')
plt.loglog(jetnodect['Mass 50pc'],jetnodect['1mm flux density (Jy)'],'v',color='blue',label='Jet non-detection')
plt.loglog(nojetnodect['Mass 50pc'],nojetnodect['1mm flux density (Jy)'],'v',color='red',label='No jet non-detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 50pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
plt.loglog(jetdect['Mass 25pc'],jetdect['1mm flux density (Jy)'],'o',color='blue',label='Jet')
plt.loglog(nojetdect['Mass 25pc'],nojetdect['1mm flux density (Jy)'],'o',color='red',label='No jet')
plt.loglog(jetnodect['Mass 25pc'],jetnodect['1mm flux density (Jy)'],'v',color='blue',label='Jet non-detection')
plt.loglog(nojetnodect['Mass 25pc'],nojetnodect['1mm flux density (Jy)'],'v',color='red',label='No jet non-detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 25pc region (Solar Masses)')
plt.ylabel('mm flux (Jy)')
# Out:
# Text(0, 0.5, 'mm flux (Jy)')

# %%
plt.loglog(data['Mass 100pc'],data['Accretion rate (M_solar/yr)'],'o')
plt.xlabel('Mass 100pc Region (Solar masses)')
plt.ylabel('Accretion rate (Solar masses/yr)')
# Out:
# Text(0, 0.5, 'Accretion rate (Solar masses/yr)')

# %%
plt.loglog(data['Mass 75pc'],data['Accretion rate (M_solar/yr)'],'o')
plt.xlabel('Mass 75pc Region (Solar masses)')
plt.ylabel('Accretion rate (Solar masses/yr)')
# Out:
# Text(0, 0.5, 'Accretion rate (Solar masses/yr)')

# %%
plt.loglog(data['Mass 50pc'],data['Accretion rate (M_solar/yr)'],'o')
plt.xlabel('Mass 50pc Region (Solar masses)')
plt.ylabel('Accretion rate (Solar masses/yr)')
# Out:
# Text(0, 0.5, 'Accretion rate (Solar masses/yr)')

# %%
plt.loglog(data['Mass 25pc'],data['Accretion rate (M_solar/yr)'],'o')
plt.xlabel('Mass 25pc Region (Solar masses)')
plt.ylabel('Accretion rate (Solar masses/yr)')
# Out:
# Text(0, 0.5, 'Accretion rate (Solar masses/yr)')

# %%
plt.loglog(liner['Mass 100pc'],liner['Accretion rate (M_solar/yr)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 100pc'],seyfert['Accretion rate (M_solar/yr)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2['Mass 100pc'],seyfert2['Accretion rate (M_solar/yr)'],'o',color='green',label='Seyfert 2')
plt.loglog(other['Mass 100pc'],other['Accretion rate (M_solar/yr)'],'o',color='yellow',label='Other')
plt.loglog(noclass['Mass 100pc'],noclass['Accretion rate (M_solar/yr)'],'o',color='black',label='No class')
plt.xlabel('Mass 100pc Region (Solar masses)')
plt.ylabel('Accretion rate (Solar masses/yr)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.loglog(liner['Mass 75pc'],liner['Accretion rate (M_solar/yr)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 75pc'],seyfert['Accretion rate (M_solar/yr)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2['Mass 75pc'],seyfert2['Accretion rate (M_solar/yr)'],'o',color='green',label='Seyfert 2')
plt.loglog(other['Mass 75pc'],other['Accretion rate (M_solar/yr)'],'o',color='yellow',label='Other')
plt.loglog(noclass['Mass 75pc'],noclass['Accretion rate (M_solar/yr)'],'o',color='black',label='No class')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass 75pc Region (Solar masses)')
plt.ylabel('Accretion rate (Solar masses/yr)')
# Out:
# Text(0, 0.5, 'Accretion rate (Solar masses/yr)')

# %%
plt.loglog(liner['Mass 50pc'],liner['Accretion rate (M_solar/yr)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 50pc'],seyfert['Accretion rate (M_solar/yr)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2['Mass 50pc'],seyfert2['Accretion rate (M_solar/yr)'],'o',color='green',label='Seyfert 2')
plt.loglog(other['Mass 50pc'],other['Accretion rate (M_solar/yr)'],'o',color='yellow',label='Other')
plt.loglog(noclass['Mass 50pc'],noclass['Accretion rate (M_solar/yr)'],'o',color='black',label='No class')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass 50pc Region (Solar masses)')
plt.ylabel('Accretion rate (Solar masses/yr)')
# Out:
# Text(0, 0.5, 'Accretion rate (Solar masses/yr)')

# %%
plt.loglog(liner['Mass 25pc'],liner['Accretion rate (M_solar/yr)'],'o',color='blue',label='LINER')
plt.loglog(seyfert['Mass 25pc'],seyfert['Accretion rate (M_solar/yr)'],'o',color='red',label='Seyfert')
plt.loglog(seyfert2['Mass 25pc'],seyfert2['Accretion rate (M_solar/yr)'],'o',color='green',label='Seyfert 2')
plt.loglog(other['Mass 25pc'],other['Accretion rate (M_solar/yr)'],'o',color='yellow',label='Other')
plt.loglog(noclass['Mass 25pc'],noclass['Accretion rate (M_solar/yr)'],'o',color='black',label='No class')
plt.xlabel('Mass 25pc Region (Solar masses)')
plt.ylabel('Accretion rate (Solar masses/yr)')
# Out:
# Text(0, 0.5, 'Accretion rate (Solar masses/yr)')

# %%
cnd100pc=data[['Mass 100pc','Accretion rate (M_solar/yr)']]

# %%
cnd100pcnew=cnd100pc.dropna()

# %%
stats.spearmanr(cnd100pcnew['Mass 100pc'],cnd100pcnew['Accretion rate (M_solar/yr)'])
# Out:
# SpearmanrResult(correlation=0.6714285714285713, pvalue=0.0061277667888201)

# %%
cnd75pc=data[['Mass 75pc','Accretion rate (M_solar/yr)']]

# %%
cnd75pcnew=cnd75pc.dropna()

# %%
stats.spearmanr(cnd75pcnew['Mass 75pc'],cnd75pcnew['Accretion rate (M_solar/yr)'])
# Out:
# SpearmanrResult(correlation=0.5560439560439561, pvalue=0.038943650418660554)

# %%
cnd50pc=data[['Mass 50pc','Accretion rate (M_solar/yr)']]

# %%
cnd50pcnew=cnd50pc.dropna()

# %%
stats.spearmanr(cnd50pcnew['Mass 50pc'],cnd50pcnew['Accretion rate (M_solar/yr)'])
# Out:
# SpearmanrResult(correlation=0.5636363636363637, pvalue=0.07095173447637536)

# %%
cnd25pc=data[['Mass 25pc','Accretion rate (M_solar/yr)']]

# %%
cnd25pcnew=cnd25pc.dropna()

# %%
stats.spearmanr(cnd25pcnew['Mass 25pc'],cnd25pcnew['Accretion rate (M_solar/yr)'])
# Out:
# SpearmanrResult(correlation=0.6, pvalue=0.28475697986529375)

# %%
dustmass=data['Dust Mass']
gasmass=data['Mass beam width']
print(gasmass)
# Out:
# 0              NaN
# 1     4.610000e+07
# 2     3.270000e+08
# 3     1.070000e+07
# 4     1.170000e+04
# 5     6.420000e+07
# 6     1.810000e+06
# 7     1.350000e+07
# 8     2.410000e+06
# 9     8.070000e+06
# 10    1.690000e+06
# 11    3.860000e+05
# 12             NaN
# 13    2.320000e+07
# 14             NaN
# 15    4.580000e+06
# 16    1.480000e+07
# 17             NaN
# 18    8.790000e+07
# 19             NaN
# 20    6.750000e+03
# 21    8.270000e+05
# 22    1.500000e+07
# 23    1.390000e+07
# 24    2.030000e+05
# 25             NaN
# 26    7.060000e+05
# 27    2.340000e+08
# 28    2.870000e+06
# 29             NaN
# 30    1.500000e+07
# 31    7.210000e+05
# 32    2.210000e+06
# 33    1.350000e+09
# 34    5.930000e+07
# Name: Mass beam width, dtype: float64

# %%
gastodust=gasmass/dustmass

# %%
data['Gas to dust ratio']=gastodust

# %%
data.head(40)
# Out:
#        Galaxy  X-ray flux density(Jy)  X-ray Luminosity (L_solar)  \
# 0     Frl1146            7.930000e-07                6.720000e+09
# 1       FRL49            1.540000e-06                4.810000e+09
# 2      MRK567                     NaN                         NaN
# 3     NGC0383            1.650000e-09                3.320000e+06
# 4     NGC0404            1.300000e-09                5.330000e+03
# 5     NGC0449            5.590000e-09                9.830000e+06
# 6     NGC0524            3.450000e-10                9.330000e+04
# 7     NGC0612            1.030000e-07                6.990000e+08
# 8     NGC0708            5.140000e-08                7.910000e+07
# 9     NGC1194            6.970000e-08                9.100000e+07
# 10    NGC1387            6.050000e-10                1.090000e+05
# 11    NGC1574                     NaN                         NaN
# 12    NGC2110            1.720000e-06                9.880000e+08
# ...

# %%
print(data[['Galaxy','Gas to dust ratio']])
# Out:
#        Galaxy  Gas to dust ratio
# 0     Frl1146                NaN
# 1       FRL49           8.366606
# 2      MRK567                NaN
# 3     NGC0383           0.047556
# 4     NGC0404           4.355920
# 5     NGC0449          30.571429
# 6     NGC0524           0.760504
# 7     NGC0612           0.038136
# 8     NGC0708           0.676966
# 9     NGC1194           2.037879
# 10    NGC1387           5.348101
# 11    NGC1574           0.406744
# 12    NGC2110                NaN
# 13    NGC3169          25.692137
# 14    NGC3351                NaN
# 15    NGC3368                NaN
# 16    NGC3607          14.800000
# 17    NGC3862                NaN
# 18    NGC4061           5.022857
# 19    NGC4261                NaN
# 20    NGC4429           0.113828
# 21    NGC4435           5.513333
# 22    NGC4438         138.888889
# 23    NGC4501          63.181818
# 24    NGC4697           4.300847
# 25    NGC4826                NaN
# 26    NGC5064           2.846774
# ...

# %%
j=data[data['Radio Jet']=='Yes']
nj=data[data['Radio Jet']=='No']
jetgd=j['Gas to dust ratio']
nojetgd=nj['Gas to dust ratio']

# %%
plt.hist(nojetgd,10,label='No jet',color='red')
plt.hist(jetgd,10,label='Jet',color='blue')
plt.xlabel('Gas to dust ratio')
plt.ylabel('Count')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
# Out:
# /home/jacob/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/jacob/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
print(nojetgd)
# Out:
# 1       8.366606
# 2            NaN
# 4       4.355920
# 5      30.571429
# 6       0.760504
# 9       2.037879
# 10      5.348101
# 11      0.406744
# 12           NaN
# 16     14.800000
# 20      0.113828
# 21      5.513333
# 22    138.888889
# 24      4.300847
# 25           NaN
# 26      2.846774
# 27     58.500000
# 29           NaN
# 30           NaN
# 31      0.089677
# 33    178.807947
# 34           NaN
# Name: Gas to dust ratio, dtype: float64

# %%
plt.loglog(data['Total Mass'],data['Gas to dust ratio'],'o')
plt.xlabel('Total Mass (Solar Masses)')
plt.ylabel('Gas to dust Ratio')
# Out:
# Text(0, 0.5, 'Gas to dust Ratio')

# %%
plt.loglog(j['Total Mass'],j['Gas to dust ratio'],'o',color='blue',label='Jet')
plt.loglog(nj['Total Mass'],nj['Gas to dust ratio'],'o',color='red',label='No Jet')
plt.xlabel('Total Mass (Solar Masses)')
plt.ylabel('Gas to dust Ratio')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
logstmassjet=j['Stellar Mass (Log)']
stmassj=10**(logstmassjet)
logstmassnojet=nj['Stellar Mass (Log)']
stmassnj=10**(logstmassnojet)

# %%
plt.loglog(stmassj,j['Gas to dust ratio'],'o',color='blue',label='Jet')
plt.loglog(stmassnj,nj['Gas to dust ratio'],'o',color='red',label='No Jet')
plt.xlabel('Stellar Mass (Solar Masses)')
plt.ylabel('Gas to dust Ratio')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
radiolumj=jet['Radio Luminosity (L_solar)']*3.828e26
radiolumnj=nojet['Radio Luminosity (L_solar)']*3.828e26

# %%
plt.loglog(jet['Mass 100pc'],radiolumj,'o',color='blue',label='Jet')
plt.loglog(nojet['Mass 100pc'],radiolumnj,'o',color='red',label='No Jet')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('Radio Luminosity (W)')
# Out:
# Text(0, 0.5, 'Radio Luminosity (W)')

# %%
xraylumj=jet['X-ray Luminosity (L_solar)']*3.828e26
xraylumnj=nojet['X-ray Luminosity (L_solar)']*3.828e26

# %%
plt.loglog(jet['Mass 100pc'],xraylumj,'o',color='blue',label='Jet')
plt.loglog(nojet['Mass 100pc'],xraylumnj,'o',color='red',label='No Jet')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('X-Ray Luminosity (W)')
# Out:
# Text(0, 0.5, 'X-Ray Luminosity (W)')

# %%
jdect=jetdect['1mm flux density (Jy)']*1e-26
jdectdist=jetdect['Distance (Mpc)']*3.09e22
jdectlum=jdect*4*math.pi*jdectdist**2*jetdect['1mm frequency (Hz)']
jnodect=jetnodect['1mm flux density (Jy)']*1e-26
jnodectdist=jetnodect['Distance (Mpc)']*3.09e22
jnodectlum=jnodect*4*math.pi*jnodectdist**2*jetnodect['1mm frequency (Hz)']
njdect=nojetdect['1mm flux density (Jy)']*1e-26
njdectdist=nojetdect['Distance (Mpc)']*3.09e22
njdectlum=njdect*4*math.pi*njdectdist**2*nojetdect['1mm frequency (Hz)']
njnodect=nojetnodect['1mm flux density (Jy)']*1e-26
njnodectdist=nojetnodect['Distance (Mpc)']*3.09e22
njnodectlum=njnodect*4*math.pi*njnodectdist**2*nojetnodect['1mm frequency (Hz)']

# %%
plt.loglog(jetdect['Mass 100pc'],jdectlum,'o',color='blue',label='Jet')
plt.loglog(nojetdect['Mass 100pc'],njdectlum,'o',color='red',label='No Jet')
plt.loglog(jetnodect['Mass 100pc'],jnodectlum,'v',color='blue',label='Jet non-detection')
plt.loglog(nojetnodect['Mass 100pc'],njnodectlum,'v',color='red',label='No Jet non-detection')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Mass of a 100pc region (Solar Masses)')
plt.ylabel('mm Luminosity (W)')
# Out:
# Text(0, 0.5, 'mm Luminosity (W)')

# %%
specjjet=j['Spectral Index']
specnojet=nj['Spectral Index']

# %%
plt.hist(specnojet,10,label='No Jet',color='red')
plt.hist(specjjet,10,label='Jet',color='blue')
plt.xlabel('Spectral Index')
plt.ylabel('Count')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
# Out:
# /home/jacob/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/jacob/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
linerspec=liner['Spectral Index']
#seyfertspec=seyfert['Spectral Index']
seyfert2spec=seyfert2['Spectral Index']
#otherspec=other['Spectral Index']
noclassspec=noclass['Spectral Index']

# %%
#plt.hist(seyfertspec,15,label='Seyfert')
plt.hist(seyfert2spec,10,label='Seyfert 2',color='green')
#plt.hist(otherspec,15,label='Other')
plt.hist(noclassspec,10,label='No class',color='black')
plt.hist(linerspec,10,label='LINER',color='blue')
plt.xlabel('Spectral Index')
plt.ylabel('Count')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.plot(data['Spectral Index'],data['Radio Flux (Jy)'],'o')
plt.yscale('log')
plt.xlabel('Spectral Index')
plt.ylabel('Radio Flux (Jy)')
# Out:
# Text(0, 0.5, 'Radio Flux (Jy)')

# %%
plt.plot(data['Spectral Index'],data['X-ray flux density(Jy)'],'o')
plt.yscale('log')
plt.xlabel('Spectral Index')
plt.ylabel('X-ray Flux (Jy)')
# Out:
# Text(0, 0.5, 'X-ray Flux (Jy)')

# %%
plt.plot(detections['Spectral Index'],detections['1mm flux density (Jy)'],'o')
plt.plot(nodetection['Spectral Index'],nodetection['1mm flux density (Jy)'],'v')
plt.yscale('log')
plt.xlabel('Spectal Index')
plt.ylabel('1mm Flux Density (Jy)')
# Out:
# Text(0, 0.5, '1mm Flux Density (Jy)')

# %%
j=data[data['Radio Jet']=='Yes']
nj=data[data['Radio Jet']=='No']

# %%
sfrj=j['Star Formation Rate']
sfrnj=nj['Star Formation Rate']

# %%
plt.hist(np.log10(sfrnj),10,label='No Jet',color='red')
plt.hist(np.log10(sfrj),10,label='Jet',color='blue')
plt.xlabel('Star formation rate (Solar Masses/yr)')
plt.ylabel('Count')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
beammass=data['Mass beam width']
starformationrate=data['Star Formation Rate']

# %%
deplt=beammass/starformationrate
data['Depletion time']=deplt
depltj=j['Depletion time']
depltnj=nj['Depletion time']

# %%
plt.hist(np.log10(depltnj),label='No Jet', color='Red')
plt.hist(np.log10(depltj),label='Jet',color='Blue')
plt.xlabel('Log Depletion Time')
plt.ylabel('Count')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.scatter(np.log10(depltj),j['Spectral Index'],label='Jet',color='Blue')
plt.scatter(np.log10(depltnj),nj['Spectral Index'],label='No Jet', color='Red')
plt.xlabel('Log Depletion Time')
plt.ylabel('Spectral Index')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
print(data[['Galaxy','Depletion time','Spectral Index']])
# Out:
#        Galaxy  Depletion time  Spectral Index
# 0     Frl1146             NaN           -0.35
# 1       FRL49    7.103236e+06           -1.33
# 2      MRK567             NaN             NaN
# 3     NGC0383    4.029221e+04            0.33
# 4     NGC0404    3.900000e+06             NaN
# 5     NGC0449    2.547619e+07            1.60
# 6     NGC0524    6.156463e+05           -0.27
# 7     NGC0612    3.344564e+04           -0.66
# 8     NGC0708    5.644028e+05           -1.75
# 9     NGC1194    1.916865e+06            1.95
# 10    NGC1387    4.333333e+06           -0.02
# 11    NGC1574    3.271186e+05            0.48
# 12    NGC2110             NaN           -0.52
# 13    NGC3169    2.035088e+07           -0.61
# 14    NGC3351             NaN             NaN
# 15    NGC3368             NaN             NaN
# 16    NGC3607    1.174603e+07           -0.60
# 17    NGC3862             NaN           -1.18
# 18    NGC4061    4.336458e+06           -2.41
# ...

# %%
kpcbeamj=j['Beam Width']/1000
kpcbeamnj=nj['Beam Width']/1000
sfrsdj=j['Star Formation Rate']/(math.pi*kpcbeamj**2)
sfrsdnj=nj['Star Formation Rate']/(math.pi*kpcbeamnj**2)
logsfrsdj=np.log10(sfrsdj)
logsfrsdnj=np.log10(sfrsdnj)
masssdj=j['Mass beam width']/(math.pi*j['Beam Width']**2)
masssdnj=nj['Mass beam width']/(math.pi*nj['Beam Width']**2)
logmasssdj=np.log10(masssdj)
logmasssdnj=np.log10(masssdnj)

# %%
kpcbeam=data['Beam Width']/1000
sfrsd=data['Star Formation Rate']/(math.pi*kpcbeam**2)
masssd=data['Mass beam width']/(math.pi*data['Beam Width']**2)

# %%
data['Star formation SD']=sfrsd
data['Gas surface density']=masssd

# %%
print(data[['Galaxy','Spectral Index','Star formation SD','Gas surface density','Depletion time']])
# Out:
#        Galaxy  Spectral Index  Star formation SD  Gas surface density  \
# 0     Frl1146           -0.35                inf                  NaN
# 1       FRL49           -1.33       3.470747e+02          2465.353452
# 2      MRK567             NaN                NaN         11934.304902
# 3     NGC0383            0.33       4.608044e+04          1856.682980
# 4     NGC0404             NaN       1.530091e+03          5967.354059
# 5     NGC0449            1.60       1.798133e+01           458.095686
# 6     NGC0524           -0.27       6.967059e+02           428.924392
# 7     NGC0612           -0.66       8.604030e+03           287.767328
# 8     NGC0708           -1.75       2.340151e+03          1320.787909
# 9     NGC1194            1.95       2.907506e+02           557.329517
# 10    NGC1387           -0.02       7.655111e+01           331.721463
# 11    NGC1574            0.48       1.579659e+03           516.735959
# ...

# %%
ksmsd=np.logspace(-1,4)
kssfrsd=2.5e-4*ksmsd**(1.4)
logksmsd=np.log10(ksmsd)
logkssfrsd=np.log10(kssfrsd)

# %%
print(logmasssdj,logsfrsdj)
# Out:
# 0          NaN
# 3     3.268738
# 7     2.459041
# 8     3.120833
# 13    3.403872
# 14         NaN
# 15    3.659953
# 17         NaN
# 18    2.544894
# 19         NaN
# 23    3.386434
# 28    2.977728
# 32    2.835044
# dtype: float64 0          inf
# 3     4.663517
# 7     3.934702
# 8     3.369244
# 13    2.095289
# 14         NaN
# 15         NaN
# 17         inf
# 18    1.907759
# 19         inf
# 23    1.674783
# 28         NaN
# 32    4.143865
# dtype: float64

# %%
plt.scatter(logmasssdj,logsfrsdj,color='blue',label='Jet')
plt.scatter(logmasssdnj,logsfrsdnj,color='red',label='No Jet')
plt.plot(logksmsd,logkssfrsd)
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
plt.xlabel('Molecular mass surface density ($M_\odot/pc^2$)')
plt.ylabel('Star formation surface density ($M_\odot/Yr/kpc^2$)')
# Out:
# Text(0, 0.5, 'Star formation surface density ($M_\\odot/Yr/kpc^2$)')

# %%
Mix=data[data['Emission mech']=='Mix']
Radio=data[data['Emission mech']=='Radio']

# %%
plt.plot(Mix['Spectral Index'],Mix['1mm flux density (Jy)'],'o',color='yellow',label='Mix')
plt.plot(Radio['Spectral Index'],Radio['1mm flux density (Jy)'],'o',color='blue',label='Radio')
plt.yscale('log')
plt.xlabel('Spectral Index')
plt.ylabel('1mm continnum flux density (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
radiodf=Radio[['Spectral Index','1mm flux density (Jy)']]
radiodfn=radiodf.dropna()
stats.spearmanr(radiodfn['Spectral Index'],radiodfn['1mm flux density (Jy)'])
# Out:
# SpearmanrResult(correlation=0.6538461538461539, pvalue=0.015348516732105476)

# %%
totmass=data['Total Mass']
massbeam=data['Mass beam width']

# %%
frac=massbeam/totmass

# %%
totdustmass=data['Dust Mass']

# %%
beamdustmass=frac*totdustmass

# %%
data['Beam Dust Mass']=beamdustmass

# %%
print(data[['Galaxy','Beam Dust Mass','Dust Mass','Nuclear dust mass']])
# Out:
#        Galaxy  Beam Dust Mass    Dust Mass  Nuclear dust mass
# 0     Frl1146             NaN    7440000.0         45000000.0
# 1       FRL49    7.257457e+04    5510000.0         19000000.0
# 2      MRK567             NaN          NaN                NaN
# 3     NGC0383    1.563312e+06  225000000.0        350000000.0
# 4     NGC0404    2.027497e+01       2686.0                NaN
# 5     NGC0449    1.357704e+05    2100000.0          8500000.0
# 6     NGC0524    7.624425e+04    2380000.0          2000000.0
# 7     NGC0612    8.817343e+05  354000000.0        498000000.0
# 8     NGC0708    1.297973e+04    3560000.0        390000000.0
# 9     NGC1194    8.431979e+05    3960000.0          1300000.0
# 10    NGC1387    1.424107e+03     316000.0          2800000.0
# 11    NGC1574    1.526308e+04     949000.0           140000.0
# 12    NGC2110             NaN   20800000.0         10000000.0
# 13    NGC3169    5.109659e+04     903000.0          7500000.0
# ...

# %%
plt.loglog(Radio['Mass 100pc'],Radio['1mm flux density (Jy)'],'o',color='blue',label='Radio')
plt.loglog(Mix['Mass 100pc'],Mix['1mm flux density (Jy)'],'o',color='yellow',label='Mix')
plt.xlabel('Mass of 100pc region')
plt.ylabel('1mm continuum flux density (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.loglog(Radio['Mass 75pc'],Radio['1mm flux density (Jy)'],'o',color='blue',label='Radio')
plt.loglog(Mix['Mass 75pc'],Mix['1mm flux density (Jy)'],'o',color='yellow',label='Mix')
plt.xlabel('Mass of 75pc region')
plt.ylabel('1mm continuum flux density (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.loglog(Radio['Mass 50pc'],Radio['1mm flux density (Jy)'],'o',color='blue',label='Radio')
plt.loglog(Mix['Mass 50pc'],Mix['1mm flux density (Jy)'],'o',color='yellow',label='Mix')
plt.xlabel('Mass of 50pc region')
plt.ylabel('1mm continuum flux density (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.loglog(Radio['Mass 25pc'],Radio['1mm flux density (Jy)'],'o',color='blue',label='Radio')
plt.loglog(Mix['Mass 25pc'],Mix['1mm flux density (Jy)'],'o',color='yellow',label='Mix')
plt.xlabel('Mass of 25pc region')
plt.ylabel('1mm continuum flux density (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
plt.loglog(Radio['Mass beam width'],Radio['1mm flux density (Jy)'],'o',color='blue',label='Radio')
plt.loglog(Mix['Mass beam width'],Mix['1mm flux density (Jy)'],'o',color='yellow',label='Mix')
plt.xlabel('Mass of beam width')
plt.ylabel('1mm continuum flux density (Jy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
jt=data[data['Radio Jet']=='Yes']
njt=data[data['Radio Jet']=='No']

# %%
mmj=jt['1mm flux density (Jy)']/1e-3
mmnj=njt['1mm flux density (Jy)']/1e-3

# %%
plt.plot(jt['Spectral Index'],mmj,'o',color='blue',label='Jet')
plt.plot(njt['Spectral Index'],mmnj,'o',color='red',label='No jet')
plt.yscale('log')
plt.xlabel('Spectral Index')
plt.ylabel('1mm continuum flux density (mJy)')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)

# %%
dt=data[data['Detection']=='Yes']
mass100pc=dt['Mass 100pc']
mass75pc=dt['Mass 75pc']
mass50pc=dt['Mass 50pc']
mmflux=dt['1mm flux density (Jy)']
mmmj=mmflux/1e-3
SI=dt['Spectral Index']
print(SI)
# Out:
# 0    -0.35
# 1    -1.33
# 3     0.33
# 4      NaN
# 5     1.60
# 6    -0.27
# 7    -0.66
# 8    -1.75
# 9     1.95
# 10   -0.02
# 11    0.48
# 12   -0.52
# 13   -0.61
# 16   -0.60
# 17   -1.18
# 18   -2.41
# 19   -0.69
# 20   -0.28
# 21    1.17
# 22   -2.17
# 23    1.36
# 24   -2.13
# 25     NaN
# 26    1.13
# 27     NaN
# 29   -1.54
# 31    0.39
# 32   -0.11
# 33   -0.83
# Name: Spectral Index, dtype: float64

# %%
cmap=sauron
plt.scatter(mass100pc,mmmj,c=SI,cmap=cmap,plotnonfinite=True)
#plt.scatter(mass100pc[4],mmmj[4])
plt.xscale('log')
plt.yscale('log')
cmap.set_bad('black')
plt.colorbar(label='Spectral Index')
plt.xlabel('Mass 100pc')
plt.ylabel('1mm continuum emission (mJy)')
# Out:
# Text(0, 0.5, '1mm continuum emission (mJy)')

# %%
plt.scatter(mass75pc,mmmj,c=SI,cmap=cmap,plotnonfinite=True)
#plt.scatter(mass100pc[4],mmmj[4])
plt.xscale('log')
plt.yscale('log')
cmap.set_bad('black')
plt.colorbar(label='Spectral Index')
plt.xlabel('Mass 75pc')
plt.ylabel('1mm continuum emission (mJy)')
# Out:
# Text(0, 0.5, '1mm continuum emission (mJy)')

# %%
plt.scatter(mass50pc,mmmj,c=SI,cmap=cmap)
#plt.scatter(mass100pc[4],mmmj[4])
plt.xscale('log')
plt.yscale('log')
cmap.set_bad('black')
plt.colorbar(label='Spectral Index')
plt.clim(-2.2,1.95,)
plt.xlabel('Mass 50pc')
plt.ylabel('1mm continuum emission (mJy)')
# Out:
# Text(0, 0.5, '1mm continuum emission (mJy)')

# %%
WISDOM=pd.read_csv('Documents/WISDOM_basic_params(1).csv')

# %%
synch=WISDOM[WISDOM['Mech']=='Synch']
synchn=synch.dropna(subset=['Type'])
thermal=WISDOM[WISDOM['Mech']=='Thermal']

# %%
plt.hist(synchn['Type'],label=r'$\alpha$ <0',color='yellow',alpha=0.7)
plt.hist(thermal['Type'],label=r'$\alpha$ >0',color='green',alpha=0.7)
plt.xlabel('Galaxy Type')
plt.ylabel('Count')
plt.legend(ncol=1)

# %%
synchmh2=synch['MH2']
logsynchmh2=np.log10(synchmh2.astype(float))
thermmh2=thermal['MH2']
logthermmh2=np.log10(thermmh2.astype(float))
plt.hist(logsynchmh2,label='Synchrotron Dominated',color='yellow')
plt.hist(logthermmh2,label='Thermal Dominated',color='green')
plt.xlabel('Log MH2 Mass')
plt.ylabel('Count')
plt.legend(ncol=1)
# Out:
# /home/jacob/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/jacob/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
synchlogmstar=synch['LogMstar'].astype(float)
thermlogmstar=thermal['LogMstar'].astype(float)
plt.hist(thermlogmstar,6,label=r'$\alpha$>0',color='green',alpha=0.7)
plt.hist(synchlogmstar,6,label=r'$\alpha$<0',color='yellow',alpha=0.7)
plt.xlabel('log$(M_{*})$')
plt.ylabel('Count')
plt.legend(ncol=1)

# %%
synchlogsfr=synch['LogSFR'].astype(float)
thermlogsfr=thermal['LogSFR'].astype(float)
plt.hist(synchlogsfr,label='Synchrotron Dominated',color='yellow')
plt.hist(thermlogsfr,label='Thermal Dominared',color='green')
plt.xlabel('Log SFR')
plt.ylabel('Count')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
# Out:
# /home/jacob/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/jacob/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.scatter(synch['LogMstar'],synch['Spectral Index'],color='yellow',label='Sychrotron Dominated')
plt.scatter(thermal['LogMstar'],thermal['Spectral Index'],color='green',label='Thermal Dominated')
plt.xlabel('LogMstar')
plt.ylabel('Spectral Index')
plt.legend(bbox_to_anchor=(1, 0), loc='lower left', ncol=1)
